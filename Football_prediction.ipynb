# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv")

# %%
matches.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result   gf   ga  ...  match report  notes    sh   sot  dist   fk   pk  \
# 0      L  0.0  1.0  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 1      W  5.0  0.0  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 2      W  5.0  0.0  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 3      W  1.0  0.0  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 4      D  0.0  0.0  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
#
#   pkatt season             team
# 0   0.0   2022  Manchester City
# ...

# %%
matches.shape
# Out:
# (1389, 28)

# %%
matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Chelsea"].sort_values("date")
# Out:
#      Unnamed: 0        date   time            comp         round  day venue  \
# 743           0  2020-09-14  20:15  Premier League   Matchweek 1  Mon  Away
# 744           1  2020-09-20  16:30  Premier League   Matchweek 2  Sun  Home
# 745           3  2020-09-26  17:30  Premier League   Matchweek 3  Sat  Away
# 746           5  2020-10-03  12:30  Premier League   Matchweek 4  Sat  Home
# 747           6  2020-10-17  15:00  Premier League   Matchweek 5  Sat  Home
# ..          ...         ...    ...             ...           ...  ...   ...
# 60           44  2022-03-13  14:00  Premier League  Matchweek 29  Sun  Home
# 61           47  2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home
# 62           49  2022-04-09  15:00  Premier League  Matchweek 32  Sat  Away
# 63           52  2022-04-20  19:45  Premier League  Matchweek 25  Wed  Home
# 64           53  2022-04-24  14:00  Premier League  Matchweek 34  Sun  Home
#
# ...

# %%
matches.dtypes
# Out:
# Unnamed: 0        int64
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]
del matches["notes"]

# %%
matches.head()
# Out:
#    Unnamed: 0        date   time        round  day venue result   gf   ga  \
# 0           1  2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0
# 1           2  2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0
# 2           3  2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0
# 3           4  2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0
# 4           6  2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...          referee  match report    sh   sot  dist   fk  \
# 0       Tottenham  ...   Anthony Taylor  Match Report  18.0   4.0  16.9  1.0
# 1    Norwich City  ...     Graham Scott  Match Report  16.0   4.0  17.3  1.0
# 2         Arsenal  ...  Martin Atkinson  Match Report  25.0  10.0  14.3  0.0
# 3  Leicester City  ...     Paul Tierney  Match Report  25.0   8.0  14.0  0.0
# 4     Southampton  ...    Jonathan Moss  Match Report  16.0   1.0  15.7  1.0
#
#     pk pkatt  season             team
# ...

# %%
del matches["Unnamed: 0"]

# %%
matches.head()
# Out:
#          date   time        round  day venue result   gf   ga        opponent  \
# 0  2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0       Tottenham
# 1  2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0    Norwich City
# 2  2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0         Arsenal
# 3  2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0  Leicester City
# 4  2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0     Southampton
#
#     xg  ...          referee  match report    sh   sot  dist   fk   pk  pkatt  \
# 0  1.9  ...   Anthony Taylor  Match Report  18.0   4.0  16.9  1.0  0.0    0.0
# 1  2.7  ...     Graham Scott  Match Report  16.0   4.0  17.3  1.0  0.0    0.0
# 2  3.8  ...  Martin Atkinson  Match Report  25.0  10.0  14.3  0.0  0.0    0.0
# 3  2.9  ...     Paul Tierney  Match Report  25.0   8.0  14.0  0.0  0.0    0.0
# 4  1.1  ...    Jonathan Moss  Match Report  16.0   1.0  15.7  1.0  0.0    0.0
#
#    season             team
# ...

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype(int)

# %%
matches.head()
# Out:
#         date   time        round  day venue result   gf   ga        opponent  \
# 0 2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0       Tottenham
# 1 2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0    Norwich City
# 2 2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0         Arsenal
# 3 2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0  Leicester City
# 4 2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0     Southampton
#
#     xg  ...  match report    sh   sot  dist   fk   pk pkatt  season  \
# 0  1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0    2022
# 1  2.7  ...  Match Report  16.0   4.0  17.3  1.0  0.0   0.0    2022
# 2  3.8  ...  Match Report  25.0  10.0  14.3  0.0  0.0   0.0    2022
# 3  2.9  ...  Match Report  25.0   8.0  14.0  0.0  0.0   0.0    2022
# 4  1.1  ...  Match Report  16.0   1.0  15.7  1.0  0.0   0.0    2022
#
#               team  target
# 0  Manchester City       0
# 1  Manchester City       1
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches.head()
# Out:
#         date   time        round  day venue result   gf   ga        opponent  \
# 0 2021-08-15  16:30  Matchweek 1  Sun  Away      L  0.0  1.0       Tottenham
# 1 2021-08-21  15:00  Matchweek 2  Sat  Home      W  5.0  0.0    Norwich City
# 2 2021-08-28  12:30  Matchweek 3  Sat  Home      W  5.0  0.0         Arsenal
# 3 2021-09-11  15:00  Matchweek 4  Sat  Away      W  1.0  0.0  Leicester City
# 4 2021-09-18  15:00  Matchweek 5  Sat  Home      D  0.0  0.0     Southampton
#
#     xg  ...   fk   pk  pkatt season             team target venue_code  \
# 0  1.9  ...  1.0  0.0    0.0   2022  Manchester City      0          0
# 1  2.7  ...  1.0  0.0    0.0   2022  Manchester City      1          1
# 2  3.8  ...  0.0  0.0    0.0   2022  Manchester City      1          1
# 3  2.9  ...  0.0  0.0    0.0   2022  Manchester City      1          0
# 4  1.1  ...  1.0  0.0    0.0   2022  Manchester City      0          1
#
#    opp_code  hour  day_code
# 0        18    16         6
# ...

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# target                   int64
# venue_code                int8
# opp_code                  int8
# hour                     int64
# day_code                 int64
# ...

# %% [markdown]
# **Training a Model with RandomForestClassifier**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2022-01-01']
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.6123188405797102

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Manchester City").sort_values("date")
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#           date   time         round  day venue result   gf   ga  \
# 632 2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 633 2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 634 2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 635 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 636 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ..         ...    ...           ...  ...   ...    ...  ...  ...
# 28  2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 29  2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 30  2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 31  2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 32  2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#            opponent   xg  ...  referee_code  formation_int  gf_rolling  \
# 632         Arsenal  1.5  ...           3.0            352    2.000000
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                                   date   time         round  day venue result  \
# team
# Arsenal                 898 2020-10-04  14:00   Matchweek 4  Sun  Home      W
#                         899 2020-10-17  17:30   Matchweek 5  Sat  Away      L
#                         900 2020-10-25  19:15   Matchweek 6  Sun  Home      L
#                         901 2020-11-01  16:30   Matchweek 7  Sun  Away      W
#                         902 2020-11-08  19:15   Matchweek 8  Sun  Home      L
# ...                                ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 227 2022-03-13  14:00  Matchweek 29  Sun  Away      W
#                         228 2022-03-18  20:00  Matchweek 30  Fri  Home      L
#                         229 2022-04-02  15:00  Matchweek 31  Sat  Home      W
#                         230 2022-04-08  20:00  Matchweek 32  Fri  Away      L
#                         231 2022-04-24  14:00  Matchweek 34  Sun  Away      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#           date   time         round  day venue result   gf   ga  \
# 898 2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 899 2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 900 2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 901 2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 902 2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# ..         ...    ...           ...  ...   ...    ...  ...  ...
# 227 2022-03-13  14:00  Matchweek 29  Sun  Away      W  1.0  0.0
# 228 2022-03-18  20:00  Matchweek 30  Fri  Home      L  2.0  3.0
# 229 2022-04-02  15:00  Matchweek 31  Sat  Home      W  2.0  1.0
# 230 2022-04-08  20:00  Matchweek 32  Fri  Away      L  0.0  1.0
# 231 2022-04-24  14:00  Matchweek 34  Sun  Away      L  0.0  1.0
#
#             opponent   xg  ...  referee_code  formation_int  gf_rolling  \
# 898    Sheffield Utd  0.4  ...          12.0            433    2.000000
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.625

# %%
from xgboost import XGBClassifier


def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']


    xgb = XGBClassifier(use_label_encoder=False, eval_metric='logloss')

    xgb.fit(train[predictors], train["target"])

    preds = xgb.predict(test[predictors])

    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)

    error = precision_score(test["target"], preds, average='binary')  # adjust the average parameter as needed
    accuracy = accuracy_score(test["target"], preds)

    return combined, error

combined, error = make_predictions(matches_rolling, predictors + new_cols)
print(error)

print(accuracy)
# Out:
# 0.5212765957446809

# %%
from sklearn.neighbors import KNeighborsClassifier

def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']

    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(train[predictors], train["target"])
    preds = knn.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)

    error = precision_score(test["target"], preds, average='binary')  # adjust the average parameter as needed

    return combined, error

# Assuming matches_rolling is your dataset and predictors + new_cols are your features
combined, error = make_predictions(matches_rolling, predictors + new_cols)
print(error)
# Out:
# 0.4868421052631579

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          0 2022-01-23  Arsenal         Burnley      D
# 56       1          0 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          1 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x     opponent_x  \
# 0           0            0 2022-01-23                  Arsenal        Burnley
# 1           1            0 2022-02-10                  Arsenal         Wolves
# 2           1            0 2022-02-19                  Arsenal      Brentford
# 3           1            1 2022-02-24                  Arsenal         Wolves
# 4           1            1 2022-03-06                  Arsenal        Watford
# ..        ...          ...        ...                      ...            ...
# 257         1            0 2022-03-13  Wolverhampton Wanderers        Everton
# 258         0            0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 259         1            0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 260         0            0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 261         0            0 2022-04-24  Wolverhampton Wanderers        Burnley
#
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    27
# 0    13
# Name: actual_x, dtype: int64

# %%
27/40
# Out:
# 0.675

# %% [markdown]
# Three Different type of models were used to make a model.
# 1. **RandomForestClassifier: 62.5%**
# 2. **XGBoost: 52.1%**
# 3. **K-Nearest Neighbor: 48.7%**
#
# But after modifying and cleaning data a bit, only using crosstab to calculate the accuracy, I found the most accuracy: **67.5%**
